# %% [markdown]
# # FIFA World Cup Final Data

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/elmoore/Documents/Python Data Wrangling Class/FIFA_World_Cup_Final.csv', low_memory=False)
# can look into using astype method from Pandas

# %%
df.head()
# Out:
#       user_id            status_id            created_at      screen_name  \
# 0    42670480  1018515041249890304  2018-07-15T15:18:03Z  Hema_ByrnesArmy
# 1    42670480  1018514680267071489  2018-07-15T15:16:37Z  Hema_ByrnesArmy
# 2  1001519461  1018515041128210433  2018-07-15T15:18:03Z      dobrevbrien
# 3   127377381  1018515041082068992  2018-07-15T15:18:03Z   deportesglobal
# 4   127377381  1018514868285132800  2018-07-15T15:17:22Z   deportesglobal
#
#                                                 text               source  \
# 0          Uh oh, I've just jinxed it #WorldCupFinal  Twitter for Android
# 1  France haven't had a lot of time on the ball <...  Twitter for Android
# 2     Neymar est<e1> criando monstros #WorldCupFinal  Twitter for Android
# 3  #FIFA|#MundialRusia2018|#FINAL| 16<92>| Franci...   Twitter Web Client
# 4  #FIFA|#MundialRusia2018|#FINAL| 13<92>| Franci...   Twitter Web Client
#
#    display_text_width  reply_to_status_id  reply_to_user_id  \
# ...

# %%
df.iloc[0:5, 15]
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: symbols, dtype: object
