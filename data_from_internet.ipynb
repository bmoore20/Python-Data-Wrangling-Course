# %% [markdown]
# # Ways to Get Data from/through the Internet

# %% [markdown]
# ## Best - Backend API
# - structured calls (intended by dev)
# - good for us because we get (usually) useful, clean-ish data
# - good for dev bc they have more control over what data we get

# %% [markdown]
# ## Second Best (though usually much worse) - Frontend Webscraping
# - generally loop through code rather than single call
# - frontend usually not as carefully structured as backend
# - dev has little control over requests
# - frontends change much more likely and rapidly than backend, can cause web scrapers to break

# %% [markdown]
# ## Usually worst option by far - regex
# - "I have to solve a problem with regex. Now I have two problems."

# %% [markdown]
# # Web Scrapping Example - Old Way

# %%
import urllib.request
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
source = urllib.request.urlopen('https://www.basketball-reference.com/teams/MEM/2022.html').read()

# %%
soup = BeautifulSoup(source, 'html')

# %%
table = soup.find_all('table')[1]

# %%
roster_html = soup.find(id='roster')

# %% [markdown]
# # Web Scrapping Example - Pandas

# %%
# read into DataFrame
roster = pd.read_html(str(roster_html))[0]
roster
# Out:
#     No.              Player Pos    Ht   Wt          Birth Date Unnamed: 6 Exp  \
# 0    13   Jaren Jackson Jr.  PF  6-11  242  September 15, 1999         us   3
# 1    22        Desmond Bane  SF   6-5  215       June 25, 1998         us   1
# 2     4        Steven Adams   C  6-11  265       July 20, 1993         nz   8
# 3     0   De'Anthony Melton  SG   6-2  200        May 28, 1998         us   3
# 4    21          Tyus Jones  PG   6-0  196        May 10, 1996         us   6
# 5    46        John Konchar  SG   6-5  210      March 22, 1996         us   2
# 6     1       Kyle Anderson  PF   6-9  230  September 20, 1993         us   7
# 7    15      Brandon Clarke  PF   6-8  215  September 19, 1996         ca   2
# 8     8     Ziaire Williams  SF   6-8  215  September 12, 2001         us   R
# 9    12           Ja Morant  PG   6-3  174     August 10, 1999         us   2
# 10    2  Xavier Tillman Sr.  PF   6-8  245    January 12, 1999         us   1
# 11   23      Jarrett Culver  SG   6-6  195   February 20, 1999         us   2
# 12   35      Killian Tillie   C   6-9  220       March 5, 1998         fr   1
# 13   24       Dillon Brooks  SF   6-7  225    January 22, 1996         ca   4
# 14    7        Santi Aldama  PF  6-11  224    January 10, 2001         es   R
# 15    5      Yves Pons (TW)  SF   6-6  215         May 7, 1999         ht   R
# 16   25         Sam Merrill  SG   6-4  205        May 15, 1996         us   1
# 17    3   Tyrell Terry (TW)  PG   6-2  160  September 28, 2000         us   1
#
#                     College
# 0            Michigan State
# 1                       TCU
# 2                      Pitt
# 3                       USC
# 4                      Duke
# 5         Purdue-Fort Wayne
# 6                      UCLA
# 7   San Jose State, Gonzaga
# 8                  Stanford
# 9              Murray State
# 10           Michigan State
# 11               Texas Tech
# 12                  Gonzaga
# 13                   Oregon
# 14              Loyola (MD)
# 15                Tennessee
# 16    Utah State University
# 17                 Stanford

# %%
roster_old_way = soup.find_all('table')[0]
roster_old_way
roster2 = pd.read_html(str(roster_old_way))
roster2[0]
# Out:
#     No.              Player Pos    Ht   Wt          Birth Date Unnamed: 6 Exp  \
# 0    13   Jaren Jackson Jr.  PF  6-11  242  September 15, 1999         us   3
# 1    22        Desmond Bane  SF   6-5  215       June 25, 1998         us   1
# 2     4        Steven Adams   C  6-11  265       July 20, 1993         nz   8
# 3     0   De'Anthony Melton  SG   6-2  200        May 28, 1998         us   3
# 4    21          Tyus Jones  PG   6-0  196        May 10, 1996         us   6
# 5    46        John Konchar  SG   6-5  210      March 22, 1996         us   2
# 6     1       Kyle Anderson  PF   6-9  230  September 20, 1993         us   7
# 7    15      Brandon Clarke  PF   6-8  215  September 19, 1996         ca   2
# 8     8     Ziaire Williams  SF   6-8  215  September 12, 2001         us   R
# 9    12           Ja Morant  PG   6-3  174     August 10, 1999         us   2
# 10    2  Xavier Tillman Sr.  PF   6-8  245    January 12, 1999         us   1
# 11   23      Jarrett Culver  SG   6-6  195   February 20, 1999         us   2
# 12   35      Killian Tillie   C   6-9  220       March 5, 1998         fr   1
# 13   24       Dillon Brooks  SF   6-7  225    January 22, 1996         ca   4
# 14    7        Santi Aldama  PF  6-11  224    January 10, 2001         es   R
# 15    5      Yves Pons (TW)  SF   6-6  215         May 7, 1999         ht   R
# 16   25         Sam Merrill  SG   6-4  205        May 15, 1996         us   1
# 17    3   Tyrell Terry (TW)  PG   6-2  160  September 28, 2000         us   1
#
#                     College
# 0            Michigan State
# 1                       TCU
# 2                      Pitt
# 3                       USC
# 4                      Duke
# 5         Purdue-Fort Wayne
# 6                      UCLA
# 7   San Jose State, Gonzaga
# 8                  Stanford
# 9              Murray State
# 10           Michigan State
# 11               Texas Tech
# 12                  Gonzaga
# 13                   Oregon
# 14              Loyola (MD)
# 15                Tennessee
# 16    Utah State University
# 17                 Stanford

# %% [markdown]
# # Can also do it locally ... instead of spamming urls

# %%
import pandas as pd
from bs4 import BeautifulSoup

# %%
html_file = "downloaded html file"

with open(html_file, 'rb') as f:
    soup = BeautifulSoup(f, 'lxml')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [33], in <cell line: 3>()
#       1 html_file = "downloaded html file"
# ----> 3 with open(html_file, 'rb') as f:
#       4     soup = BeautifulSoup(f, 'lxml')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'downloaded html file'

# %%
roster_html = soup.find(id='roster')
roster = pd.read_html(str(roster_html))[0]
roster
# Out:
#     No.              Player Pos    Ht   Wt          Birth Date Unnamed: 6 Exp  \
# 0    13   Jaren Jackson Jr.  PF  6-11  242  September 15, 1999         us   3
# 1    22        Desmond Bane  SF   6-5  215       June 25, 1998         us   1
# 2     4        Steven Adams   C  6-11  265       July 20, 1993         nz   8
# 3     0   De'Anthony Melton  SG   6-2  200        May 28, 1998         us   3
# 4    21          Tyus Jones  PG   6-0  196        May 10, 1996         us   6
# 5    46        John Konchar  SG   6-5  210      March 22, 1996         us   2
# 6     1       Kyle Anderson  PF   6-9  230  September 20, 1993         us   7
# 7    15      Brandon Clarke  PF   6-8  215  September 19, 1996         ca   2
# 8     8     Ziaire Williams  SF   6-8  215  September 12, 2001         us   R
# 9    12           Ja Morant  PG   6-3  174     August 10, 1999         us   2
# 10    2  Xavier Tillman Sr.  PF   6-8  245    January 12, 1999         us   1
# 11   23      Jarrett Culver  SG   6-6  195   February 20, 1999         us   2
# 12   35      Killian Tillie   C   6-9  220       March 5, 1998         fr   1
# 13   24       Dillon Brooks  SF   6-7  225    January 22, 1996         ca   4
# 14    7        Santi Aldama  PF  6-11  224    January 10, 2001         es   R
# 15    5      Yves Pons (TW)  SF   6-6  215         May 7, 1999         ht   R
# 16   25         Sam Merrill  SG   6-4  205        May 15, 1996         us   1
# 17    3   Tyrell Terry (TW)  PG   6-2  160  September 28, 2000         us   1
#
#                     College
# 0            Michigan State
# 1                       TCU
# 2                      Pitt
# 3                       USC
# 4                      Duke
# 5         Purdue-Fort Wayne
# 6                      UCLA
# 7   San Jose State, Gonzaga
# 8                  Stanford
# 9              Murray State
# 10           Michigan State
# 11               Texas Tech
# 12                  Gonzaga
# 13                   Oregon
# 14              Loyola (MD)
# 15                Tennessee
# 16    Utah State University
# 17                 Stanford

# %% [markdown]
# # Reg expressions
# - Ton of exercises in textbook

# %% [markdown]
# # API Example

# %%
import pandas as pd
import urllib.request, urllib.parse
import json

# %%
api_url = 'https://www.thecocktaildb.com/api/json/v1/1/search.php?s=margarita'

uh = urllib.request.urlopen(api_url)

data = uh.read().decode()

# %%
drinks_json = json.loads(data)
drinks_df = pd.json_normalize(drinks_json['drinks'])
drinks_df
# Out:
#   idDrink                      strDrink strDrinkAlternate  \
# 0   11007                     Margarita              None
# 1   11118                Blue Margarita              None
# 2   17216             Tommy's Margarita              None
# 3   16158            Whitecap Margarita              None
# 4   12322          Strawberry Margarita              None
# 5  178332  Smashed Watermelon Margarita              None
#
#                    strTags strVideo     strCategory                 strIBA  \
# 0  IBA,ContemporaryClassic     None  Ordinary Drink  Contemporary Classics
# 1                     None     None  Ordinary Drink                   None
# 2               IBA,NewEra     None  Ordinary Drink         New Era Drinks
# 3                     None     None   Other/Unknown                   None
# 4                     None     None  Ordinary Drink                   None
# 5                     None     None        Cocktail                   None
#
#   strAlcoholic                  strGlass  \
# 0    Alcoholic            Cocktail glass
# 1    Alcoholic            Cocktail glass
# 2    Alcoholic       Old-Fashioned glass
# 3    Alcoholic  Margarita/Coupette glass
# 4    Alcoholic            Cocktail glass
# 5    Alcoholic             Collins glass
#
#                                      strInstructions  ... strMeasure10  \
# 0  Rub the rim of the glass with the lime slice t...  ...         None
# 1  Rub rim of cocktail glass with lime juice. Dip...  ...         None
# 2    Shake and strain into a chilled cocktail glass.  ...         None
# 3  Place all ingredients in a blender and blend u...  ...         None
# 4  Rub rim of cocktail glass with lemon juice and...  ...         None
# 5  In a mason jar muddle the watermelon and 5 min...  ...         None
#
#   strMeasure11 strMeasure12 strMeasure13 strMeasure14 strMeasure15  \
# 0         None         None         None         None         None
# 1         None         None         None         None         None
# 2         None         None         None         None         None
# 3         None         None         None         None         None
# 4         None         None         None         None         None
# 5         None         None         None         None         None
#
#                                       strImageSource strImageAttribution  \
# 0  https://commons.wikimedia.org/wiki/File:Klassi...      Cocktailmarler
# 1                                               None                None
# 2                                               None                None
# 3                                               None                None
# 4                                               None                None
# 5                                               None                None
#
#   strCreativeCommonsConfirmed         dateModified
# 0                         Yes  2015-08-18 14:42:59
# 1                         Yes  2015-08-18 14:51:53
# 2                          No  2017-09-02 18:37:54
# 3                          No  2015-09-02 17:00:22
# 4                          No  2015-08-18 14:41:51
# 5                          No                 None
#
# [6 rows x 51 columns]
